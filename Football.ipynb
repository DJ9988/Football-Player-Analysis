# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FM 2023.csv')
df
# Out:
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# 4          Mohamed Salah   AM/S RL   30  185  187           Egypt
# ...                  ...       ...  ...  ...  ...             ...
# 8447          Joe Ashton       D L   16   45  135         England
# 8448          River Ries         S   17   45  135         Germany
# 8449      Halilcan Doğan       D C   23   45  -75          Turkey
# 8450        Adijat Sefer         S   17   45  135         Germany
# 8451         Linus Urban         S   17   45  135         Germany
#
#                             Club  Corners  Crossing  Dribbling  ...  \
# 0                Manchester City       14        19         15  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8452 entries, 0 to 8451
# Data columns (total 98 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Name                                 8452 non-null   object
#  1   Position                             8452 non-null   object
#  2   Age                                  8452 non-null   int64
#  3   ca                                   8452 non-null   int64
#  4   pa                                   8452 non-null   int64
#  5   Nationality                          8452 non-null   object
#  6   Club                                 8345 non-null   object
#  7   Corners                              8452 non-null   int64
#  8   Crossing                             8452 non-null   int64
#  9   Dribbling                            8452 non-null   int64
#  10  Finishing                            8452 non-null   int64
# ...

# %%
df.isnull()
# Out:
#        Name  Position    Age     ca     pa  Nationality   Club  Corners  \
# 0     False     False  False  False  False        False  False    False
# 1     False     False  False  False  False        False  False    False
# 2     False     False  False  False  False        False  False    False
# 3     False     False  False  False  False        False  False    False
# 4     False     False  False  False  False        False  False    False
# ...     ...       ...    ...    ...    ...          ...    ...      ...
# 8447  False     False  False  False  False        False  False    False
# 8448  False     False  False  False  False        False  False    False
# 8449  False     False  False  False  False        False  False    False
# 8450  False     False  False  False  False        False  False    False
# 8451  False     False  False  False  False        False  False    False
#
#       Crossing  Dribbling  ...  World reputation   Race    RCA  \
# ...

# %%
df.isnull().sum()
# Out:
# Name                                      0
# Position                                  0
# Age                                       0
# ca                                        0
# pa                                        0
#                                        ...
# Number of national team appearances       0
# Goals scored for the national team        0
# Salary                                  107
# Rental club                            7457
# UID                                       0
# Length: 98, dtype: int64

# %%
a = np.mean(df['Salary'])
a
# Out:
# 20890.90748951468

# %%
df['Salary'].fillna(a, inplace = True)
df
# Out:
# C:\Users\DJ\AppData\Local\Temp\ipykernel_2816\3893496283.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(a, inplace = True)
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# ...

# %%
df.isnull().sum()
# Out:
# Name                                      0
# Position                                  0
# Age                                       0
# ca                                        0
# pa                                        0
#                                        ...
# Number of national team appearances       0
# Goals scored for the national team        0
# Salary                                    0
# Rental club                            7457
# UID                                       0
# Length: 98, dtype: int64

# %%
df['Rental club']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 8447    NaN
# 8448    NaN
# 8449    NaN
# 8450    NaN
# 8451    NaN
# Name: Rental club, Length: 8452, dtype: object

# %%
df.drop('Rental club', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8452 entries, 0 to 8451
# Data columns (total 97 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Name                                 8452 non-null   object
#  1   Position                             8452 non-null   object
#  2   Age                                  8452 non-null   int64
#  3   ca                                   8452 non-null   int64
#  4   pa                                   8452 non-null   int64
#  5   Nationality                          8452 non-null   object
#  6   Club                                 8345 non-null   object
#  7   Corners                              8452 non-null   int64
#  8   Crossing                             8452 non-null   int64
#  9   Dribbling                            8452 non-null   int64
#  10  Finishing                            8452 non-null   int64
# ...

# %%
df.rename(columns = {'ca':'Rating', 'pa':'Potential'}, inplace = True)

# %%
df
# Out:
#                     Name  Position  Age  Rating  Potential     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31     189        189         Belgium
# 1          Kylian Mbappé   AM/S RL   23     188        197          France
# 2     Robert Lewandowski         S   33     186        190          Poland
# 3         Erling Haaland         S   22     185        195  Norway,England
# 4          Mohamed Salah   AM/S RL   30     185        187           Egypt
# ...                  ...       ...  ...     ...        ...             ...
# 8447          Joe Ashton       D L   16      45        135         England
# 8448          River Ries         S   17      45        135         Germany
# 8449      Halilcan Doğan       D C   23      45        -75          Turkey
# 8450        Adijat Sefer         S   17      45        135         Germany
# 8451         Linus Urban         S   17      45        135         Germany
#
# ...

# %%
df['Club'].isnull().sum()
# Out:
# 107

# %%
df['Club'].fillna('No Club', inplace = True)
# Out:
# C:\Users\DJ\AppData\Local\Temp\ipykernel_2816\1693491003.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Club'].fillna('No Club', inplace = True)

# %%
df
# Out:
#                     Name  Position  Age  Rating  Potential     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31     189        189         Belgium
# 1          Kylian Mbappé   AM/S RL   23     188        197          France
# 2     Robert Lewandowski         S   33     186        190          Poland
# 3         Erling Haaland         S   22     185        195  Norway,England
# 4          Mohamed Salah   AM/S RL   30     185        187           Egypt
# ...                  ...       ...  ...     ...        ...             ...
# 8447          Joe Ashton       D L   16      45        135         England
# 8448          River Ries         S   17      45        135         Germany
# 8449      Halilcan Doğan       D C   23      45        -75          Turkey
# 8450        Adijat Sefer         S   17      45        135         Germany
# 8451         Linus Urban         S   17      45        135         Germany
#
# ...

# %%
df['Club'].isnull().sum()
# Out:
# 0

# %%
#pd.set_option("display.max_rows", None)
df.isnull().sum()
# Out:
# Name                                   0
# Position                               0
# Age                                    0
# Rating                                 0
# Potential                              0
#                                       ..
# Date of birth                          0
# Number of national team appearances    0
# Goals scored for the national team     0
# Salary                                 0
# UID                                    0
# Length: 97, dtype: int64

# %%
df.drop('RCA', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Name                                   0
# Position                               0
# Age                                    0
# Rating                                 0
# Potential                              0
#                                       ..
# Date of birth                          0
# Number of national team appearances    0
# Goals scored for the national team     0
# Salary                                 0
# UID                                    0
# Length: 96, dtype: int64

# %%
df
# Out:
#                     Name  Position  Age  Rating  Potential     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31     189        189         Belgium
# 1          Kylian Mbappé   AM/S RL   23     188        197          France
# 2     Robert Lewandowski         S   33     186        190          Poland
# 3         Erling Haaland         S   22     185        195  Norway,England
# 4          Mohamed Salah   AM/S RL   30     185        187           Egypt
# ...                  ...       ...  ...     ...        ...             ...
# 8447          Joe Ashton       D L   16      45        135         England
# 8448          River Ries         S   17      45        135         Germany
# 8449      Halilcan Doğan       D C   23      45        -75          Turkey
# 8450        Adijat Sefer         S   17      45        135         Germany
# 8451         Linus Urban         S   17      45        135         Germany
#
# ...

# %%
from sklearn import linear_model

# %%
a = df.iloc[:, ~df.columns.isin(['Name', 'Position', 'Nationality', 'Club', 'Race', 'Rating', 'Date of birth'])]

# %%
b = df.iloc[0:,3]

# %%
a
# Out:
#       Age  Potential  Corners  Crossing  Dribbling  Finishing  First Touch  \
# 0      31        189       14        19         15         16           16
# 1      23        197       13        13         18         17           18
# 2      33        190        3         8         13         19           18
# 3      22        195        7        10         14         18           16
# 4      30        187       12        14         17         17           17
# ...   ...        ...      ...       ...        ...        ...          ...
# 8447   16        135        3         4          5          4            4
# 8448   17        135        2         2         11         11           11
# 8449   23        -75        1         1          1          2            4
# 8450   17        135        3         4         12          7            8
# 8451   17        135        4         2         10         13            8
#
# ...

# %%
b
# Out:
# 0       189
# 1       188
# 2       186
# 3       185
# 4       185
#        ...
# 8447     45
# 8448     45
# 8449     45
# 8450     45
# 8451     45
# Name: Rating, Length: 8452, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(a, b, test_size = 0.10, random_state = 10)

# %%
x_train
# Out:
#       Age  Potential  Corners  Crossing  Dribbling  Finishing  First Touch  \
# 1777   28        135       10        12         12         13           14
# 5232   27        126        9         9         11         12           12
# 4506   20        147        8         7         12         12           14
# 1184   24        144        4         7          9          5           11
# 6034   22        135        8        12         13          7           15
# ...   ...        ...      ...       ...        ...        ...          ...
# 4829   22        150        7         8         11          8           14
# 7291   19        -75        5         7         10         12           13
# 1344   20        -85        4         7         12          7           12
# 7293   22        140       10        10         11         11           13
# 1289   22        152       13        12         14         11           14
#
# ...

# %%
x_test
# Out:
#       Age  Potential  Corners  Crossing  Dribbling  Finishing  First Touch  \
# 5533   29        133       12        13         13         12           14
# 6083   19        -75        3         9          8          7           10
# 330    25        155        5         8         12         15           13
# 2104   24        149        4        11         13          7           11
# 4625   30        144        3         4          6          7            8
# ...   ...        ...      ...       ...        ...        ...          ...
# 491    31        150        7         8          7          7            8
# 7658   18        -75       10        11         13          8           13
# 1986   32        135       14        13         13         11           14
# 3254   34        135       12        12         14         11           14
# 6902   19        138        8         8         10         13           14
#
# ...

# %%
y_train
# Out:
# 1777    130
# 5232    120
# 4506    122
# 1184    135
# 6034    117
#        ...
# 4829    121
# 7291    100
# 1344    134
# 7293    100
# 1289    134
# Name: Rating, Length: 7606, dtype: int64

# %%
y_test
# Out:
# 5533    120
# 6083    116
# 330     147
# 2104    129
# 4625    122
#        ...
# 491     143
# 7658     91
# 1986    130
# 3254    125
# 6902    106
# Name: Rating, Length: 846, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(regression, x_train, y_train,scoring = 'neg_mean_squared_error', cv = 10)
# Out:
# array([-11.2937706 , -11.83418462,  -9.35193427, -11.2524364 ,
#         -9.67913257,  -9.08941184, -10.33645501, -10.35172854,
#         -9.22875215, -10.73285362])

# %%
mse = cross_val_score(regression, x_train, y_train, scoring = 'neg_mean_squared_error', cv = 10)

# %%
np.mean(mse)
# Out:
# -10.315065961303741

# %%
reg_pred = regression.predict(x_test)

# %%
reg_pred
# Out:
# array([120.9424735 , 115.55412384, 143.3085518 , 126.57110241,
#        122.37230652, 119.72446303, 121.09921402, 112.62959608,
#        119.9456391 , 100.8550207 ,  68.25355022, 127.25979365,
#         90.80416173,  71.3986632 , 133.04106099, 136.57502468,
#        123.84099873, 132.67564796, 124.58086456, 124.15425245,
#         91.20011577, 110.68516403, 120.86713692, 125.96644666,
#        130.2131215 , 143.08226941, 104.41429527, 122.75663599,
#        142.13616004, 123.26330806, 113.86356435,  94.63902197,
#        152.37704883, 114.34958746, 138.16482752, 156.21839496,
#         73.40962535, 129.99198119, 126.18364738, 122.29668982,
#        121.09810877, 115.08804142, 124.48544805, 126.30811286,
#        128.54820509, 137.6190949 , 121.28839244, 121.07606453,
#         62.10253768, 125.96235315, 134.33213994, 116.38116861,
#        133.97787126,  71.57021042, 125.77623769, 125.25358487,
#        105.79114948, 155.23193696,  62.59584817, 117.83435227,
# ...

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(reg_pred, y_test)

# %%
score
# Out:
# 0.9680403226849212
